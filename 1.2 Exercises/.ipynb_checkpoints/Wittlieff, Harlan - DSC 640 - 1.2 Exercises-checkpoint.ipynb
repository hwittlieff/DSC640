# %% [markdown]
# # 1.2 Exercise
# # Class: DSC 640
# # Name: Wittlieff, Harlan
# # Date: 3/23/2022

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load dataset
df = pd.read_excel('data/obama-approval-ratings.xls', index_col=0)  
df = df.reset_index()
df
# Out:
#                        Issue  Approve  Disapprove  None
# 0             Race Relations       52          38    10
# 1                  Education       49          40    11
# 2                  Terrorism       48          45     7
# 3              Energy Policy       47          42    11
# 4            Foreign Affairs       44          48     8
# 5                Environment       43          51     6
# 6          Situation in Iraq       41          53     6
# 7                      Taxes       41          54     5
# 8          Healthcare Policy       40          57     3
# 9                    Economy       38          59     3
# 10  Situation in Afghanistan       36          57     7
# 11    Federal Budget Deficit       31          64     5
# 12               Immigration       29          62     9

# %%
# Build bar chart
plt.barh(df['Issue'], df['Approve'])
plt.ylabel("Issue")
plt.xlabel("% Approval")
plt.title("Obama's Approval Ratings")
plt.show()

# %%
# Build stacked bar chart
ax = df.plot(x='Issue', kind='bar', stacked=True,
        title="Obama's Ratings by Issue")
ax.set_xlabel("Issue")
ax.set_ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
# Build a pie chart
y = np.array([df['Approve'][8],df['Disapprove'][8], df['None'][8]])
mylabels = ["Approve", "Disapprove", "None"]
plt.pie(y, labels=mylabels)
plt.title("Obama's Rating on Taxes")
plt.show()

# %%
# Create a pieplot
plt.pie(y, labels=mylabels)
plt.title("Obama's Rating on Taxes")

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

plt.show()
